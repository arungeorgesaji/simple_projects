# %%
from sklearn.linear_model import LinearRegression
import pandas as pd

# %%
s = pd.read_csv('tesla_stonks_up_and_down.csv')
s
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-06-29    3.800000    5.000000    3.508000    4.778000    4.778000
# 1     2010-06-30    5.158000    6.084000    4.660000    4.766000    4.766000
# 2     2010-07-01    5.000000    5.184000    4.054000    4.392000    4.392000
# 3     2010-07-02    4.600000    4.620000    3.742000    3.840000    3.840000
# 4     2010-07-06    4.000000    4.000000    3.166000    3.222000    3.222000
# ...          ...         ...         ...         ...         ...         ...
# 3001  2022-05-31  773.840027  778.799988  734.229980  758.260010  758.260010
# 3002  2022-06-01  755.159973  771.979980  730.919983  740.369995  740.369995
# 3003  2022-06-02  732.469971  792.630005  726.200012  775.000000  775.000000
# 3004  2022-06-03  729.679993  743.390015  700.250000  703.549988  703.549988
# 3005  2022-06-06  733.059998  734.599976  703.049988  714.840027  714.840027
#
#         Volume
# 0     93831500
# ...

# %%
x =s['Date']
x
# Out:
# 0       2010-06-29
# 1       2010-06-30
# 2       2010-07-01
# 3       2010-07-02
# 4       2010-07-06
#            ...
# 3001    2022-05-31
# 3002    2022-06-01
# 3003    2022-06-02
# 3004    2022-06-03
# 3005    2022-06-06
# Name: Date, Length: 3006, dtype: object

# %%
y=s['Close']
y
# Out:
# 0         4.778000
# 1         4.766000
# 2         4.392000
# 3         3.840000
# 4         3.222000
#            ...
# 3001    758.260010
# 3002    740.369995
# 3003    775.000000
# 3004    703.549988
# 3005    714.840027
# Name: Close, Length: 3006, dtype: float64

# %%
x = x.str.replace('-', '')
x
# Out:
# <PandasArray>
# [
# ['20100629'],
# ['20100630'],
# ['20100701'],
# ['20100702'],
# ['20100706'],
# ['20100707'],
# ['20100708'],
# ['20100709'],
# ['20100712'],
# ['20100713'],
# ['20100714'],
# ['20100715'],
# ['20100716'],
# ['20100719'],
# ['20100720'],
# ['20100721'],
# ['20100722'],
# ['20100723'],
# ['20100726'],
# ['20100727'],
# ['20100728'],
# ['20100729'],
# ['20100730'],
# ['20100802'],
# ['20100803'],
# ['20100804'],
# ['20100805'],
# ['20100806'],
# ['20100809'],
# ['20100810'],
# ['20100811'],
# ['20100812'],
# ['20100813'],
# ['20100816'],
# ['20100817'],
# ['20100818'],
# ['20100819'],
# ['20100820'],
# ['20100823'],
# ['20100824'],
# ['20100825'],
# ['20100826'],
# ['20100827'],
# ['20100830'],
# ['20100831'],
# ['20100901'],
# ['20100902'],
# ['20100903'],
# ['20100907'],
# ['20100908'],
# ['20100909'],
# ['20100910'],
# ['20100913'],
# ['20100914'],
# ['20100915'],
# ['20100916'],
# ['20100917'],
# ['20100920'],
# ['20100921'],
# ['20100922'],
# ['20100923'],
# ...
